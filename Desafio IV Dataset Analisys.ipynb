# %%
import pandas as pd
import numpy as np

midi_stats = pd.read_csv('midi_stats_v3_drop_cols_.csv',sep=",")
midi_stats
# Out:
#       Unnamed: 0 first_time_signature  cant_time_signatures    bpm  compases  \
# 0              0                  3/4                     1   80.0        64
# 1              1                  3/4                     1  100.0        64
# 2              2                  3/4                     1   80.0        65
# 3              3                  3/4                     1   90.0        80
# 4              4                  3/4                     1   70.0        64
# ...          ...                  ...                   ...    ...       ...
# 4828        4828                  4/4                     1  100.0        34
# 4829        4829                  4/4                     1  100.0        40
# 4830        4830                  4/4                     1  100.0        42
# 4831        4831                  4/4                     1  120.0       101
# 4832        4832                  2/4                     1   80.0        95
#
# ...

# %%
midi_stats.iloc[:,0:100].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4833 entries, 0 to 4832
# Data columns (total 100 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              4833 non-null   int64
#  1   first_time_signature    4833 non-null   object
#  2   cant_time_signatures    4833 non-null   int64
#  3   bpm                     4833 non-null   float64
#  4   compases                4833 non-null   int64
#  5   cant_dist_chords        4833 non-null   int64
#  6   avg_notes_quantified    4833 non-null   float64
#  7   tempo_changes           4833 non-null   int64
#  8   tonalidad               4833 non-null   object
#  9   tonalidad_escala        4833 non-null   object
#  10  scale_coverage          4833 non-null   float64
#  11  mayor_chord_coverage    4833 non-null   float64
#  12  minor_chord_coverage    4833 non-null   float64
#  13  scale_note_avg_1        4829 non-null   float64
# ...

# %%
midi_stats.iloc[:,100:200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4833 entries, 0 to 4832
# Data columns (total 100 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   length_note_1.25            2373 non-null   float64
#  1   chord_1_3_6                 1222 non-null   float64
#  2   chord_2_4_6                 865 non-null    float64
#  3   avg_simult_Reed             919 non-null    float64
#  4   inst_Bassoon                191 non-null    float64
#  5   chord_2_4+_6                450 non-null    float64
#  6   chord_2_4_5_7               550 non-null    float64
#  7   avg_simult_Strings          1336 non-null   float64
#  8   inst_Strings                464 non-null    float64
#  9   inst_String ensamble        1144 non-null   float64
#  10  inst_Oboe                   240 non-null    float64
#  11  length_note_1.375           2132 non-null   float64
#  12  ('Oboe', 0.25)              156 non-null    float64
# ...

# %%
midi_stats.iloc[:,200:300].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4833 entries, 0 to 4832
# Data columns (total 100 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   length_note_1.625         1680 non-null   float64
#  1   inst_Trombone             207 non-null    float64
#  2   ('Trombone', 0.0)         160 non-null    float64
#  3   chord_2_4_7               237 non-null    float64
#  4   avg_simult_Guitar         1981 non-null   float64
#  5   inst_Steel Guitar         532 non-null    float64
#  6   inst_Acoustic Bass        686 non-null    float64
#  7   inst_Flute                413 non-null    float64
#  8   ('Acoustic Bass', 0.375)  279 non-null    float64
#  9   ('Acoustic Bass', 0.5)    612 non-null    float64
#  10  ('Acoustic Bass', 0.625)  168 non-null    float64
#  11  ('Acoustic Bass', 0.0)    654 non-null    float64
#  12  ('Acoustic Bass', 0.25)   474 non-null    float64
# ...

# %%
midi_stats.iloc[:,300:400].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4833 entries, 0 to 4832
# Data columns (total 100 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ('Flute', 0.375)                  191 non-null    float64
#  1   ('String ensamble', 0.969)        162 non-null    float64
#  2   inst_Electric Piano               836 non-null    float64
#  3   ('Electric Piano', 0.0)           795 non-null    float64
#  4   ('Electric Piano', 0.125)         402 non-null    float64
#  5   ('Electric Piano', 0.875)         465 non-null    float64
#  6   ('Electric Piano', 0.625)         430 non-null    float64
#  7   ('Electric Piano', 0.375)         468 non-null    float64
#  8   ('Electric Piano', 0.75)          578 non-null    float64
#  9   ('Electric Piano', 0.5)           700 non-null    float64
#  10  ('Electric Piano', 0.25)          584 non-null    float64
# ...

# %%
midi_stats.describe().T[['mean','std','min','50%','75%','max']].head(50)
# Out:
#                                mean          std        min          50%  \
# Unnamed: 0              2639.000000  1524.060366   0.000000  2639.000000
# cant_time_signatures       2.265581     8.029451   1.000000     1.000000
# bpm                      108.611858    39.531545   0.000000   107.000000
# compases                 112.298352   118.606443   5.000000    95.000000
# avg_notes_quantified       0.262145     0.319898   0.000000     0.089672
# tempo_changes              0.293427     0.455375   0.000000     0.000000
# scale_coverage            89.925942    11.752697   3.370000    93.350000
# mayor_chord_coverage      46.401826    12.631795   0.000000    45.980000
# minor_chord_coverage      43.400144    11.296210   0.000000    43.420000
# scale_note_avg_1          21.964689     8.606316   0.020000    20.535000
# scale_note_avg_2          13.946603     6.683328   0.010000    14.675000
# scale_note_avg_3          13.706269     4.906125   0.020000    13.955000
# ...

# %%
midi_stats.Genero.value_counts()
# Out:
# ClassicRock     2428
# Classical       1507
# Hymns            322
# Jazz             313
# latina           254
# NEW-AGE          166
# Dance_Techno     152
# RapMusic          58
# REGGAE            43
# TANGO             36
# Name: Genero, dtype: int64

# %% [markdown]
# mask_1 = (midi_stats.avg_notes_quantified > 0.4)
# mask_2 = (midi_stats.bpm == 120)
# midi_stats[mask_1 and mask_2]

# %%
midi_stats.Grupo.value_counts().head(30)
# Out:
# Bach                          981
# Beatles                       209
# Beethoven                     174
# Midi New Real Book I          159
# Midi New Real Book II         154
# Vivaldi                       102
# Schubert                      101
# ONBE~169                       96
# Chopin                         93
# Metallica                      74
# LedZeppelin                    64
# PIANO~43                       53
# ONBEK~41                       38
# Brahms                         37
# Madonna                        37
# BeachBoys                      32
# ENYA                           29
# ELO                            26
# RollingStones                  24
# Eagles                         23
# BryanAdams                     21
# Trance                         20
# PaulMcCartney                  20
# Nirvana                        19
# BillyJoel                      19
# Rachmaninov                    19
# Genesis                        18
# ...

# %%
midi_stats.cant_time_signatures.value_counts()
# Out:
# 1      4401
# 3       198
# 2       194
# 5        65
# 7        65
# 4        57
# 9        56
# 6        38
# 8        27
# 11       25
# 12       16
# 13       15
# 15       12
# 10       10
# 14       10
# 18        8
# 17        7
# 21        7
# 25        7
# 19        5
# 16        4
# 40        3
# 42        3
# 24        3
# 36        3
# 29        2
# 20        2
# 28        2
# 46        2
# 31        2
# 27        2
# 23        2
# 22        2
# 44        2
# 56        1
# 32        1
# 52        1
# 259       1
# 33        1
# 37        1
# 119       1
# 83        1
# 59        1
# 55        1
# 51        1
# 43        1
# 39        1
# 35        1
# 58        1
# 34        1
# 171       1
# 117       1
# 57        1
# 53        1
# 41        1
# 345       1
# Name: cant_time_signatures, dtype: int64

# %%
len_mask = midi_stats.cant_time_signatures > 1
midi_stats[len_mask]
# Out:
#       Unnamed: 0 first_time_signature  cant_time_signatures    bpm  compases  \
# 36            36                  4/4                     3  100.0        41
# 37            37                  4/4                     3  100.0        46
# 113          113                  4/4                     3   70.0        47
# 148          148                  3/4                    19  104.0        18
# 184          184                  4/4                     3  100.0        46
# ...          ...                  ...                   ...    ...       ...
# 5208        5208                  4/4                     2   80.0        78
# 5212        5212                  4/4                     2   96.0        91
# 5223        5223                  4/4                     3   98.0       104
# 5235        5235                  4/4                     7   78.0        82
# 5260        5260                  4/8                     2   64.0        64
#
# ...

# %%
tema_analysis = midi_stats.loc[148,:]
tema_analysis.dropna(inplace=True)
tema_analysis.drop(['info_tracks'],inplace=True)
# Out:
# C:\Users\Patricio\anaconda3\envs\dhdsblend\lib\site-packages\pandas\core\series.py:4494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)
# C:\Users\Patricio\anaconda3\envs\dhdsblend\lib\site-packages\pandas\core\generic.py:3939: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(obj)

# %%
pd.DataFrame(tema_analysis.iloc[0:50])
# Out:
#                            148
# Unnamed: 0                 148
# first_time_signature       3/4
# cant_time_signatures        19
# bpm                        104
# compases                    18
# avg_notes_quantified         0
# tempo_changes                0
# tonalidad                    C
# tonalidad_escala             M
# scale_coverage           98.59
# mayor_chord_coverage     70.36
# minor_chord_coverage     49.99
# scale_note_avg_1         37.96
# scale_note_avg_2         24.07
# scale_note_avg_3         11.11
# scale_note_avg_4          8.33
# scale_note_avg_5          6.94
# scale_note_avg_6          6.48
# scale_note_avg_7           3.7
# avr_vertical_notes    0.944444
# duracion_seg           32.8846
# tracks_used                  3
# avg_simult_Piano      0.944444
# Piano                  6.56842
# note_num_mean               49
# note_num_std           26.8025
# note_num_min                 0
# note_num_25%             47.75
# note_num_50%                60
# ...

# %%
pd.DataFrame(tema_analysis.iloc[50:100])
# Out:
#                          148
# p                          0
# 0.5                 0.148148
# 1.0                 0.569444
# 0.0                 0.212963
# 0.25              0.00462963
# Genero             Classical
# Grupo                   Bach
# tema                013705ch
# ('Piano', 0.0)       4.05556
# ('Piano', 0.333)     2.44444
# ('Piano', 0.667)     4.05556
# ('Piano', 0.5)       1.05556
# ('Piano', 0.833)    0.333333
# 0.75              0.00462963
# 1.5                0.0601852
