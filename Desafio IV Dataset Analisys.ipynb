# %%
import pandas as pd
import numpy as np

midi_stats = pd.read_csv('midi_stats_new.csv',sep=",")
midi_stats
# Out:
#       Unnamed: 0 time_signatures tonalidad tonalidad_escala  scale_coverage  \
# 0     0           ['3/4']         F         M                93.52
# 1     1           ['3/4']         G         M                97.66
# 2     2           ['3/4']         D         m                93.79
# 3     3           ['3/4']         G         M                98.40
# 4     4           ['3/4']         F         M                98.46
# ...  ..               ...        ..        ..                  ...
# 5134  5134        ['4/4']         G         M                98.81
# 5135  5135        ['4/4']         A         M                99.66
# 5136  5136        ['4/4']         A#        m                99.52
# 5137  5137        ['4/4']         C         M                98.75
# 5138  5138        ['4/4']         C         m                99.65
#
#       mayor_chord_coverage  minor_chord_coverage   sc_1   sc_2   sc_3  ...  \
# 0     44.66                 41.99                 17.18  15.65  14.89  ...
# ...

# %%
midi_stats.iloc[:,0:99].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5139 entries, 0 to 5138
# Data columns (total 99 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5139 non-null   int64
#  1   time_signatures         5139 non-null   object
#  2   tonalidad               5139 non-null   object
#  3   tonalidad_escala        5139 non-null   object
#  4   scale_coverage          5139 non-null   float64
#  5   mayor_chord_coverage    5139 non-null   float64
#  6   minor_chord_coverage    5139 non-null   float64
#  7   sc_1                    5134 non-null   float64
#  8   sc_2                    5127 non-null   float64
#  9   sc_3                    5108 non-null   float64
#  10  sc_4                    5116 non-null   float64
#  11  sc_5                    5128 non-null   float64
#  12  sc_6                    5090 non-null   float64
#  13  sc_7                    5111 non-null   float64
# ...

# %%
midi_stats.iloc[:,100:167].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5139 entries, 0 to 5138
# Data columns (total 67 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   crash                  2157 non-null   float64
#  1   Cynbal                 1287 non-null   float64
#  2   Muted Trumpet          40 non-null     float64
#  3   Snare                  2797 non-null   float64
#  4   Tambourine             883 non-null    float64
#  5   Tubular Bells          62 non-null     float64
#  6   Guitar noise           37 non-null     float64
#  7   Hand clap              650 non-null    float64
#  8   Clean Electric Guitar  659 non-null    float64
#  9   Marimba                68 non-null     float64
#  10  HiHat                  2661 non-null   float64
#  11  Side Stick             736 non-null    float64
#  12  Cabasa                 452 non-null    float64
#  13  Maracas                350 non-null    float64
# ...

# %%
midi_stats[].describe()
# Out:
#         Unnamed: 0  scale_coverage  mayor_chord_coverage  \
# count  5139.000000  5139.000000     5139.000000
# mean   2569.000000  90.710000       47.057046
# std    1483.645847  11.475553       12.637717
# min    0.000000     3.370000        0.000000
# 25%    1284.500000  87.740000       39.330000
# 50%    2569.000000  94.120000       46.980000
# 75%    3853.500000  97.990000       55.445000
# max    5138.000000  100.020000      90.600000
#
#        minor_chord_coverage         sc_1         sc_2         sc_3  \
# count  5139.000000           5134.000000  5127.000000  5108.000000
# mean   43.786904             22.074772    14.296491    13.792790
# std    11.205361             8.393936     6.748392     4.795921
# min    0.000000              0.020000     0.020000     0.020000
# 25%    37.840000             16.670000    9.120000     11.780000
# 50%    43.940000             20.780000    15.280000    14.120000
# 75%    50.295000             26.290000    19.020000    15.940000
# ...

# %%
midi_stats.Genero.value_counts()
# Out:
# ClassicRock     2477
# Classical       1522
# Hymns           325
# latina          281
# Dance_Techno    175
# NEW-AGE         172
# Jazz            84
# RapMusic        59
# REGGAE          44
# Name: Genero, dtype: int64

# %%
midi_stats.Grupo.value_counts().head(30)
# Out:
# Bach                          990
# Beatles                       209
# Beethoven                     176
# Schubert                      104
# Vivaldi                       103
# ONBE~169                      100
# Chopin                        93
# Metallica                     74
# LedZeppelin                   66
# PIANO~43                      53
# ONBEK~41                      40
# Brahms                        37
# Madonna                       37
# BeachBoys                     31
# ENYA                          28
# ELO                           28
# RollingStones                 24
# Eagles                        23
# Trance                        23
# BryanAdams                    22
# PaulMcCartney                 21
# Rachmaninov                   19
# BillyJoel                     19
# Nirvana                       19
# CreedenceClearwaterRevival    18
# Genesis                       18
# Carpennters                   17
# Styx                          17
# ...
