# %%
import pandas as pd
import numpy as np

midi_stats = pd.read_csv('midi_stats_new_drop_cols.csv',sep=",")
midi_stats
# Out:
#       Unnamed: 0 first_time_signature  cant_time_signatures    bpm  compases  \
# 0              0                  3/4                     1   80.0        64
# 1              1                  3/4                     1  100.0        64
# 2              2                  3/4                     1   80.0        65
# 3              3                  3/4                     1   90.0        80
# 4              4                  3/4                     1   70.0        64
# ...          ...                  ...                   ...    ...       ...
# 5274        5274                  4/4                     1  120.0       108
# 5275        5275                  4/4                     1  120.0       109
# 5276        5276                  4/4                     1  120.0        87
# 5277        5277                  4/4                     1  120.0        87
# 5278        5278                  4/4                     1  128.0        74
#
# ...

# %%
midi_stats.iloc[:,0:100].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 100 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  5279 non-null   int64
#  1   first_time_signature        5279 non-null   object
#  2   cant_time_signatures        5279 non-null   int64
#  3   bpm                         5279 non-null   float64
#  4   compases                    5279 non-null   int64
#  5   avg_notes_quantified        5279 non-null   float64
#  6   tempo_changes               5279 non-null   int64
#  7   tonalidad                   5279 non-null   object
#  8   tonalidad_escala            5279 non-null   object
#  9   scale_coverage              5279 non-null   float64
#  10  mayor_chord_coverage        5279 non-null   float64
#  11  minor_chord_coverage        5279 non-null   float64
#  12  scale_note_avg_1            5274 non-null   float64
# ...

# %%
midi_stats.iloc[:,100:200].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 100 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   avg_simult_Synth          424 non-null    float64
#  1   Brass Section             389 non-null    float64
#  2   Synth                     590 non-null    float64
#  3   ('Brass Section', 0.75)   268 non-null    float64
#  4   ('Brass Section', 0.5)    271 non-null    float64
#  5   ('Brass Section', 0.0)    295 non-null    float64
#  6   ('Synth', 0.25)           322 non-null    float64
#  7   ('Synth', 0.75)           351 non-null    float64
#  8   ('Synth', 0.5)            390 non-null    float64
#  9   ('Synth', 0.625)          311 non-null    float64
#  10  ('Synth', 0.0)            468 non-null    float64
#  11  ('Synth', 0.875)          335 non-null    float64
#  12  ('Synth', 0.125)          282 non-null    float64
# ...

# %%
midi_stats.iloc[:,200:300].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 100 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ('Piano', 0.031)                  428 non-null    float64
#  1   ('Piano', 0.781)                  313 non-null    float64
#  2   3.5                               706 non-null    float64
#  3   Electric Piano                    934 non-null    float64
#  4   ('Electric Piano', 0.0)           875 non-null    float64
#  5   ('Electric Piano', 0.125)         455 non-null    float64
#  6   ('Electric Piano', 0.875)         529 non-null    float64
#  7   ('Electric Piano', 0.625)         487 non-null    float64
#  8   ('Electric Piano', 0.375)         525 non-null    float64
#  9   ('Electric Piano', 0.75)          644 non-null    float64
#  10  ('Electric Piano', 0.5)           776 non-null    float64
# ...

# %%
midi_stats.iloc[:,300:400].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5279 entries, 0 to 5278
# Data columns (total 100 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ('Tambourine', 0.375)             411 non-null    float64
#  1   ('Tambourine', 0.5)               471 non-null    float64
#  2   ('Tambourine', 0.625)             408 non-null    float64
#  3   ('Tambourine', 0.75)              637 non-null    float64
#  4   ('Tambourine', 0.875)             413 non-null    float64
#  5   ('Drum', 0.188)                   305 non-null    float64
#  6   ('Drum', 0.688)                   320 non-null    float64
#  7   ('Drum', 0.938)                   377 non-null    float64
#  8   ('Clean Electric Guitar', 0.25)   500 non-null    float64
#  9   ('Hand clap', 0.25)               392 non-null    float64
#  10  ('HiHat', 0.25)                   2471 non-null   float64
# ...

# %%
midi_stats.describe().T[['mean','std','min','50%','max']].head(50)
# Out:
#                                mean          std        min          50%  \
# Unnamed: 0              2639.000000  1524.060366   0.000000  2639.000000
# cant_time_signatures       2.265581     8.029451   1.000000     1.000000
# bpm                      108.611858    39.531545   0.000000   107.000000
# compases                 112.298352   118.606443   5.000000    95.000000
# avg_notes_quantified       0.262145     0.319898   0.000000     0.089672
# tempo_changes              0.293427     0.455375   0.000000     0.000000
# scale_coverage            89.925942    11.752697   3.370000    93.350000
# mayor_chord_coverage      46.401826    12.631795   0.000000    45.980000
# minor_chord_coverage      43.400144    11.296210   0.000000    43.420000
# scale_note_avg_1          21.964689     8.606316   0.020000    20.535000
# scale_note_avg_2          13.946603     6.683328   0.010000    14.675000
# scale_note_avg_3          13.706269     4.906125   0.020000    13.955000
# ...

# %%
midi_stats.Genero.value_counts()
# Out:
# ClassicRock     2428
# Classical       1507
# Hymns            322
# Jazz             313
# latina           254
# NEW-AGE          166
# Dance_Techno     152
# RapMusic          58
# REGGAE            43
# TANGO             36
# Name: Genero, dtype: int64

# %%
midi_stats.Grupo.value_counts().head(30)
# Out:
# Bach                          981
# Beatles                       209
# Beethoven                     174
# Midi New Real Book I          159
# Midi New Real Book II         154
# Vivaldi                       102
# Schubert                      101
# ONBE~169                       96
# Chopin                         93
# Metallica                      74
# LedZeppelin                    64
# PIANO~43                       53
# ONBEK~41                       38
# Madonna                        37
# Brahms                         37
# BeachBoys                      32
# ENYA                           29
# ELO                            26
# RollingStones                  24
# Eagles                         23
# BryanAdams                     21
# Trance                         20
# PaulMcCartney                  20
# Nirvana                        19
# BillyJoel                      19
# Rachmaninov                    19
# CreedenceClearwaterRevival     18
# ...

# %%
midi_stats.cant_time_signatures.value_counts()
# Out:
# 1      4401
# 3       198
# 2       194
# 5        65
# 7        65
# 4        57
# 9        56
# 6        38
# 8        27
# 11       25
# 12       16
# 13       15
# 15       12
# 10       10
# 14       10
# 18        8
# 17        7
# 21        7
# 25        7
# 19        5
# 16        4
# 40        3
# 42        3
# 24        3
# 36        3
# 29        2
# 20        2
# 28        2
# 46        2
# 31        2
# 27        2
# 23        2
# 22        2
# 44        2
# 56        1
# 32        1
# 52        1
# 259       1
# 33        1
# 37        1
# 119       1
# 83        1
# 59        1
# 55        1
# 51        1
# 43        1
# 39        1
# 35        1
# 58        1
# 34        1
# 171       1
# 117       1
# 57        1
# 53        1
# 41        1
# 345       1
# Name: cant_time_signatures, dtype: int64

# %%
len_mask = midi_stats.cant_time_signatures > 1
midi_stats[len_mask]
# Out:
#       Unnamed: 0 first_time_signature  cant_time_signatures    bpm  compases  \
# 36            36                  4/4                     3  100.0        41
# 37            37                  4/4                     3  100.0        46
# 113          113                  4/4                     3   70.0        47
# 148          148                  3/4                    19  104.0        18
# 184          184                  4/4                     3  100.0        46
# ...          ...                  ...                   ...    ...       ...
# 5208        5208                  4/4                     2   80.0        78
# 5212        5212                  4/4                     2   96.0        91
# 5223        5223                  4/4                     3   98.0       104
# 5235        5235                  4/4                     7   78.0        82
# 5260        5260                  4/8                     2   64.0        64
#
# ...
